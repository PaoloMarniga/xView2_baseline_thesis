# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy==1.26.4 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 15)) (1.26.4)
# Requirement already satisfied: pandas==2.2.2 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 16)) (2.2.2)
# Requirement already satisfied: shapely==2.0.4 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 17)) (2.0.4)
# Requirement already satisfied: opencv-python==4.9.0.80 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 18)) (4.9.0.80)
# Requirement already satisfied: pillow==10.3.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 19)) (10.3.0)
# Requirement already satisfied: matplotlib==3.8.4 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 21)) (3.8.4)
# Requirement already satisfied: scikit-learn==1.4.2 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 22)) (1.4.2)
# Requirement already satisfied: torch==2.8.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 24)) (2.8.0)
# Requirement already satisfied: torchvision==0.23.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 25)) (0.23.0)
# Requirement already satisfied: jupyter==1.0.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 27)) (1.0.0)
# Requirement already satisfied: ipykernel==6.29.4 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 28)) (6.29.4)
# Requirement already satisfied: tqdm==4.66.2 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 29)) (4.66.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from pandas==2.2.2->-r requirements.txt (line 16)) (2025.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from pandas==2.2.2->-r requirements.txt (line 16)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from pandas==2.2.2->-r requirements.txt (line 16)) (2025.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 21)) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 21)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 21)) (3.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 21)) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 21)) (26.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 21)) (6.5.2)
# Requirement already satisfied: cycler>=0.10 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 21)) (0.12.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from scikit-learn==1.4.2->-r requirements.txt (line 22)) (3.6.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from scikit-learn==1.4.2->-r requirements.txt (line 22)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from scikit-learn==1.4.2->-r requirements.txt (line 22)) (1.5.3)
# Requirement already satisfied: filelock in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from torch==2.8.0->-r requirements.txt (line 24)) (3.19.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from torch==2.8.0->-r requirements.txt (line 24)) (1.14.0)
# Requirement already satisfied: networkx in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from torch==2.8.0->-r requirements.txt (line 24)) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from torch==2.8.0->-r requirements.txt (line 24)) (3.1.6)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from torch==2.8.0->-r requirements.txt (line 24)) (4.15.0)
# Requirement already satisfied: fsspec in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from torch==2.8.0->-r requirements.txt (line 24)) (2025.10.0)
# Requirement already satisfied: qtconsole in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter==1.0.0->-r requirements.txt (line 27)) (5.7.2)
# Requirement already satisfied: nbconvert in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter==1.0.0->-r requirements.txt (line 27)) (7.17.1)
# Requirement already satisfied: jupyter-console in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter==1.0.0->-r requirements.txt (line 27)) (6.6.3)
# Requirement already satisfied: notebook in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter==1.0.0->-r requirements.txt (line 27)) (7.5.5)
# Requirement already satisfied: ipywidgets in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter==1.0.0->-r requirements.txt (line 27)) (8.1.8)
# Requirement already satisfied: comm>=0.1.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.29.4->-r requirements.txt (line 28)) (0.2.3)
# Requirement already satisfied: pyzmq>=24 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.29.4->-r requirements.txt (line 28)) (27.1.0)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.29.4->-r requirements.txt (line 28)) (1.8.19)
# Requirement already satisfied: psutil in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.29.4->-r requirements.txt (line 28)) (7.2.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.29.4->-r requirements.txt (line 28)) (5.14.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.29.4->-r requirements.txt (line 28)) (0.2.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.29.4->-r requirements.txt (line 28)) (5.8.1)
# Requirement already satisfied: nest-asyncio in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.29.4->-r requirements.txt (line 28)) (1.6.0)
# Requirement already satisfied: appnope in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.29.4->-r requirements.txt (line 28)) (0.1.4)
# Requirement already satisfied: tornado>=6.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.29.4->-r requirements.txt (line 28)) (6.5.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.29.4->-r requirements.txt (line 28)) (8.6.3)
# Requirement already satisfied: ipython>=7.23.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.29.4->-r requirements.txt (line 28)) (8.18.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib==3.8.4->-r requirements.txt (line 21)) (3.23.0)
# Requirement already satisfied: jedi>=0.16 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.29.4->-r requirements.txt (line 28)) (0.19.2)
# Requirement already satisfied: pygments>=2.4.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.29.4->-r requirements.txt (line 28)) (2.19.2)
# Requirement already satisfied: stack-data in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.29.4->-r requirements.txt (line 28)) (0.6.3)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.29.4->-r requirements.txt (line 28)) (3.0.52)
# Requirement already satisfied: exceptiongroup in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.29.4->-r requirements.txt (line 28)) (1.3.1)
# Requirement already satisfied: decorator in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.29.4->-r requirements.txt (line 28)) (5.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.29.4->-r requirements.txt (line 28)) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.29.4->-r requirements.txt (line 28)) (0.8.5)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->ipykernel==6.29.4->-r requirements.txt (line 28)) (8.7.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.29.4->-r requirements.txt (line 28)) (4.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==6.29.4->-r requirements.txt (line 28)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==6.29.4->-r requirements.txt (line 28)) (0.5.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2->-r requirements.txt (line 16)) (1.15.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch==2.8.0->-r requirements.txt (line 24)) (1.3.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipywidgets->jupyter==1.0.0->-r requirements.txt (line 27)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from ipywidgets->jupyter==1.0.0->-r requirements.txt (line 27)) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jinja2->torch==2.8.0->-r requirements.txt (line 24)) (3.0.3)
# Requirement already satisfied: defusedxml in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (4.14.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (1.5.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (0.10.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (3.2.0)
# Requirement already satisfied: bleach[css]!=5.0.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (6.2.0)
# Requirement already satisfied: nbformat>=5.7 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (5.10.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (0.3.0)
# Requirement already satisfied: webencodings in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (1.4.0)
# Requirement already satisfied: jsonschema>=2.6 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (4.25.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (2.21.2)
# Requirement already satisfied: referencing>=0.28.4 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (0.27.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (2025.9.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (26.1.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (2.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (2.17.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (0.2.4)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (2.28.0)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.6 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (4.5.6)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (2.1.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (25.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (1.9.0)
# Requirement already satisfied: anyio>=3.1.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (4.12.1)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (0.25.0)
# Requirement already satisfied: overrides>=5.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (7.7.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (0.5.4)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (0.12.1)
# Requirement already satisfied: idna>=2.8 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (3.13)
# Requirement already satisfied: argon2-cffi-bindings in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (25.1.0)
# Requirement already satisfied: rfc3339-validator in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (0.1.1)
# Requirement already satisfied: pyyaml>=5.3 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (6.0.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (4.0.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (24.11.1)
# Requirement already satisfied: isoduration in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (20.11.0)
# Requirement already satisfied: fqdn in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (1.1.0)
# Requirement already satisfied: uri-template in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (1.3.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.6,>=4.5.6->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (2.0.5)
# Requirement already satisfied: setuptools>=41.1.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab<4.6,>=4.5.6->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (58.0.4)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.6,>=4.5.6->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (0.28.1)
# Requirement already satisfied: tomli>=1.2.2 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.6,>=4.5.6->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (2.4.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.6,>=4.5.6->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (2.3.1)
# Requirement already satisfied: certifi in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (0.16.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (0.14.0)
# Requirement already satisfied: requests>=2.31 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (2.32.5)
# Requirement already satisfied: babel>=2.10 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (2.18.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (3.4.7)
# Requirement already satisfied: lark>=1.2.2 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from rfc3987-syntax>=1.1.0->jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 27)) (2.23)
# Requirement already satisfied: arrow>=0.15.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from isoduration->jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 27)) (1.4.0)
# Requirement already satisfied: qtpy>=2.4.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from qtconsole->jupyter==1.0.0->-r requirements.txt (line 27)) (2.4.3)
# Requirement already satisfied: ipython_pygments_lexers in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from qtconsole->jupyter==1.0.0->-r requirements.txt (line 27)) (1.1.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.29.4->-r requirements.txt (line 28)) (3.0.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.29.4->-r requirements.txt (line 28)) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.29.4->-r requirements.txt (line 28)) (0.2.3)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import torch
import numpy as np
import pandas as pd
import cv2
import shapely

print("All packages loaded successfully")
print("Torch version:", torch.__version__)
# Out:
# All packages loaded successfully
# Torch version: 2.8.0

# %%
import sys
# !{sys.executable} model/OOD_dro_classifier.py
# Out:
# Loading data...
#
# Split sizes:
# Train: 166544
# Test: 46833
# Hold: 53403
#
# Train label distribution:
# damage_label
# no-damage       120576
# major-damage     17327
# minor-damage     17063
# destroyed        11578
# Name: count, dtype: int64
#
# Test label distribution:
# damage_label
# no-damage       37859
# destroyed        6089
# major-damage     2260
# minor-damage      625
# Name: count, dtype: int64
#
# Hold label distribution:
# damage_label
# no-damage       38388
# minor-damage     8428
# destroyed        3558
# major-damage     3029
# Name: count, dtype: int64
#
# Number of training groups: 4
# Group mapping:
#   0: hurricane-harvey
#   1: hurricane-matthew
#   2: mexico-earthquake
#   3: palu-tsunami
#   4: __unknown__
#
# Unseen TEST groups mapped to __unknown__: ['guatemala-volcano', 'hurricane-florence', 'midwest-flooding', 'santa-rosa-wildfire']
# Unseen HOLD groups mapped to __unknown__: ['hurricane-michael', 'socal-fire']
#
# Using device: mps
#
# Starting DRO-lite training...
# Epoch 1/10: 100%|██████████████| 5205/5205 [28:31<00:00,  3.04it/s, loss=1.1927]
# Epoch 01 | Train Loss: 0.8617 | OOD Test Loss: 1.1936 | OOD Test Macro F1: 0.3039 | Time: 30.68 min
# Epoch 2/10: 100%|██████████████| 5205/5205 [29:50<00:00,  2.91it/s, loss=0.5994]
# Epoch 02 | Train Loss: 0.7605 | OOD Test Loss: 1.1089 | OOD Test Macro F1: 0.3608 | Time: 48.04 min
# Epoch 3/10: 100%|████████████| 5205/5205 [2:17:59<00:00,  1.59s/it, loss=0.5803]
# Epoch 03 | Train Loss: 0.7058 | OOD Test Loss: 1.0054 | OOD Test Macro F1: 0.4245 | Time: 140.36 min
# Epoch 4/10: 100%|██████████████| 5205/5205 [30:31<00:00,  2.84it/s, loss=0.8406]
# Epoch 04 | Train Loss: 0.6452 | OOD Test Loss: 0.9994 | OOD Test Macro F1: 0.4065 | Time: 33.04 min
# Epoch 5/10: 100%|██████████████| 5205/5205 [30:19<00:00,  2.86it/s, loss=0.9778]
# Epoch 05 | Train Loss: 0.5857 | OOD Test Loss: 0.9735 | OOD Test Macro F1: 0.3856 | Time: 32.45 min
# Epoch 6/10: 100%|██████████████| 5205/5205 [27:42<00:00,  3.13it/s, loss=0.7604]
# Epoch 06 | Train Loss: 0.5009 | OOD Test Loss: 1.0129 | OOD Test Macro F1: 0.4253 | Time: 29.76 min
# Epoch 7/10: 100%|██████████████| 5205/5205 [26:50<00:00,  3.23it/s, loss=0.7467]
# Epoch 07 | Train Loss: 0.4296 | OOD Test Loss: 1.0704 | OOD Test Macro F1: 0.4048 | Time: 29.01 min
# Epoch 8/10: 100%|██████████████| 5205/5205 [28:23<00:00,  3.06it/s, loss=0.9043]
# Epoch 08 | Train Loss: 0.3731 | OOD Test Loss: 1.1905 | OOD Test Macro F1: 0.3867 | Time: 30.63 min
# Epoch 9/10: 100%|██████████████| 5205/5205 [28:08<00:00,  3.08it/s, loss=0.2788]
# Epoch 09 | Train Loss: 0.3187 | OOD Test Loss: 1.0681 | OOD Test Macro F1: 0.4109 | Time: 30.33 min
# Epoch 10/10: 100%|█████████████| 5205/5205 [27:13<00:00,  3.19it/s, loss=0.5479]
# Epoch 10 | Train Loss: 0.2890 | OOD Test Loss: 1.0380 | OOD Test Macro F1: 0.4040 | Time: 29.24 min
#
# Evaluating best DRO-lite model...
#
# Final OOD TEST Macro F1: 0.4253
#               precision    recall  f1-score   support
#
#    no-damage     0.9380    0.5980    0.7304     37859
# minor-damage     0.0178    0.1776    0.0323       625
# major-damage     0.0900    0.4655    0.1509      2260
#    destroyed     0.8959    0.7026    0.7876      6089
#
#     accuracy                         0.5996     46833
#    macro avg     0.4854    0.4859    0.4253     46833
# weighted avg     0.8793    0.5996    0.7005     46833
#
#
# OOD TEST prediction distribution:
# no-damage: 24135
# minor-damage: 6240
# major-damage: 11683
# destroyed: 4775
#
# OOD TEST true distribution:
# no-damage: 37859
# minor-damage: 625
# major-damage: 2260
# destroyed: 6089
#
# Final OOD HOLD Macro F1: 0.3351
#               precision    recall  f1-score   support
#
#    no-damage     0.7871    0.7526    0.7695     38388
# minor-damage     0.2282    0.2886    0.2549      8428
# major-damage     0.0799    0.1149    0.0942      3029
#    destroyed     0.3452    0.1636    0.2220      3558
#
#     accuracy                         0.6040     53403
#    macro avg     0.3601    0.3299    0.3351     53403
# weighted avg     0.6294    0.6040    0.6135     53403
#
#
# OOD HOLD prediction distribution:
# no-damage: 36705
# minor-damage: 10656
# major-damage: 4356
# destroyed: 1686
#
# OOD HOLD true distribution:
# no-damage: 38388
# minor-damage: 8428
# major-damage: 3029
# destroyed: 3558
#
# Saved all DRO-lite outputs successfully.
# /Users/paolo/Desktop/OOD_training_outputs/baseline_resnet50_dro/best_model.pt
# /Users/paolo/Desktop/OOD_training_outputs/baseline_resnet50_dro/training_history.csv
# /Users/paolo/Desktop/OOD_training_outputs/baseline_resnet50_dro/summary.json

# %%
from pathlib import Path

OUTPUT_DIR = Path.home() / "Desktop" / "OOD_training_outputs" / "baseline_resnet50_dro"

for f in sorted(OUTPUT_DIR.glob("*")):
    print(f.name)
# Out:
# best_model.pt
# ood_hold_classification_report.json
# ood_hold_confusion_matrix.npy
# ood_hold_preds.npy
# ood_hold_targets.npy
# ood_test_classification_report.json
# ood_test_confusion_matrix.npy
# ood_test_preds.npy
# ood_test_targets.npy
# summary.json
# training_history.csv

# %% [markdown]
# # Thesis Baseline Setup
#
# This notebook documents the workflow for the thesis baseline on xBD/xView2 using a building-level classification pipeline.
#
# ---
#
# ## Core Principle
#
# - Preprocessing and model training run directly in Python
# - Notebook is used for:
#   - Data inspection
#   - Sanity checks
#   - Training control
#   - Evaluation
#   - Visualization
#
# The official xView2 Docker pipeline is not used as the main experimental setup, because the thesis isolates the damage classification task from localization by using ground truth building polygons.
#
# ---
#
# ## Required Data
#
# Download and place on Desktop:
#
# - `train`
# - `test`
# - `hold`
#
# These contain:
# - images
# - labels
#
# ---
#
# ## Main Experimental Design
#
# The thesis does not use the original end to end competition pipeline as the primary method.
#
# Instead, the pipeline is:
#
# 1. Read ground truth polygons from label JSON files
# 2. Build a building-level metadata table
# 3. Extract pre/post building crops
# 4. Stack pre and post crops into 6-channel tensors
# 5. Train a ResNet50-based classifier on damage labels
#
# This removes localization as a confounding factor and isolates the classification task.
#
# ---
#
# ## Required External Apps
#
# - `miniconda` or another Python environment manager
#
#
# ## Create Environment
#
# ```bash
# conda create -n thesis_xview python=3.10
# conda activate thesis_xview

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 15)) (1.26.4)
# Requirement already satisfied: matplotlib in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 16)) (3.9.4)
# Requirement already satisfied: tqdm in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 17)) (4.67.3)
# Collecting libtiff
#   Using cached libtiff-0.4.2.tar.gz (129 kB)
# Requirement already satisfied: scipy in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 19)) (1.13.1)
# Requirement already satisfied: Pillow in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 20)) (11.3.0)
# Requirement already satisfied: scikit-image in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 21)) (0.24.0)
# Requirement already satisfied: opencv-python in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 22)) (4.9.0.80)
# Collecting imgaug
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#      |████████████████████████████████| 948 kB 390 kB/s eta 0:00:01
# Requirement already satisfied: IPython in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 24)) (8.18.1)
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#      |████████████████████████████████| 323 kB 469 kB/s eta 0:00:01
# Collecting keras
#   Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 2.7 MB/s eta 0:00:01
# Collecting imantics
#   Using cached imantics-0.1.12-py3-none-any.whl
# Collecting simplification
#   Downloading simplification-0.7.13.tar.gz (1.4 MB)
#      |████████████████████████████████| 1.4 MB 1.1 MB/s eta 0:00:01
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/bs/rzk6qg1902vgdlp6h22t8bq40000gn/T/pip-build-env-42t6_521/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/bs/rzk6qg1902vgdlp6h22t8bq40000gn/T/pip-build-env-42t6_521/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/bs/rzk6qg1902vgdlp6h22t8bq40000gn/T/pip-build-env-42t6_521/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/bs/rzk6qg1902vgdlp6h22t8bq40000gn/T/pip-build-env-42t6_521/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/bs/rzk6qg1902vgdlp6h22t8bq40000gn/T/pip-build-env-42t6_521/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/bs/rzk6qg1902vgdlp6h22t8bq40000gn/T/pip-build-env-42t6_521/overlay'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   WARNING: Generating metadata for package simplification produced metadata for project name unknown. Fix your #egg=simplification fragments.
# WARNING: Discarding https://files.pythonhosted.org/packages/5e/43/40887f0edc7a523264fe8dbfe83f762f57b0efcca21cdce62d609310e68a/simplification-0.7.13.tar.gz#sha256=4ff7a7ef43eb2359a822b981c22c2cd8d58d92d84aa13c715662ec1887d5854e (from https://pypi.org/simple/simplification/) (requires-python:>=3.9). Requested unknown from https://files.pythonhosted.org/packages/5e/43/40887f0edc7a523264fe8dbfe83f762f57b0efcca21cdce62d609310e68a/simplification-0.7.13.tar.gz#sha256=4ff7a7ef43eb2359a822b981c22c2cd8d58d92d84aa13c715662ec1887d5854e (from -r requirements.txt (line 28)) has inconsistent name: filename has 'simplification', but metadata has 'UNKNOWN'
#   Downloading simplification-0.7.12-cp39-cp39-macosx_11_0_arm64.whl (254 kB)
#      |████████████████████████████████| 254 kB 396 kB/s eta 0:00:01
# Requirement already satisfied: scikit-learn in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 29)) (1.6.1)
# Requirement already satisfied: chainer in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 30)) (7.8.1)
# Collecting tensorboard
#   Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 1.0 MB/s eta 0:00:01
# Requirement already satisfied: tensorboardX in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 32)) (2.6.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 16)) (4.60.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 16)) (6.5.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 16)) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 16)) (26.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 16)) (3.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 16)) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 16)) (1.4.7)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from scikit-image->-r requirements.txt (line 21)) (0.5)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from scikit-image->-r requirements.txt (line 21)) (2024.8.30)
# Requirement already satisfied: imageio>=2.33 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from scikit-image->-r requirements.txt (line 21)) (2.37.2)
# Requirement already satisfied: networkx>=2.8 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from scikit-image->-r requirements.txt (line 21)) (3.2.1)
# Requirement already satisfied: Shapely in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from imgaug->-r requirements.txt (line 23)) (1.8.5.post1)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from imgaug->-r requirements.txt (line 23)) (1.15.0)
# Requirement already satisfied: stack-data in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from IPython->-r requirements.txt (line 24)) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from IPython->-r requirements.txt (line 24)) (5.14.3)
# Requirement already satisfied: exceptiongroup in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from IPython->-r requirements.txt (line 24)) (1.3.1)
# Requirement already satisfied: matplotlib-inline in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from IPython->-r requirements.txt (line 24)) (0.2.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from IPython->-r requirements.txt (line 24)) (2.19.2)
# Requirement already satisfied: decorator in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from IPython->-r requirements.txt (line 24)) (5.2.1)
# Requirement already satisfied: typing-extensions in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from IPython->-r requirements.txt (line 24)) (4.15.0)
# Requirement already satisfied: pexpect>4.3 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from IPython->-r requirements.txt (line 24)) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from IPython->-r requirements.txt (line 24)) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from IPython->-r requirements.txt (line 24)) (3.0.52)
# Collecting pyproj>=3.3.0
#   Downloading pyproj-3.6.1-cp39-cp39-macosx_11_0_arm64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 732 kB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.4.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from geopandas->-r requirements.txt (line 25)) (2.3.3)
# Collecting Shapely
#   Downloading shapely-2.0.7-cp39-cp39-macosx_11_0_arm64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 824 kB/s eta 0:00:01
# Collecting pyogrio>=0.7.2
#   Downloading pyogrio-0.11.1-cp39-cp39-macosx_12_0_arm64.whl (19.5 MB)
#      |████████████████████████████████| 19.5 MB 598 kB/s eta 0:00:01
# Collecting namex
#   Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Collecting h5py
#   Using cached h5py-3.14.0-cp39-cp39-macosx_11_0_arm64.whl (2.8 MB)
# Collecting absl-py
#   Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Collecting rich
#   Downloading rich-15.0.0-py3-none-any.whl (310 kB)
#      |████████████████████████████████| 310 kB 329 kB/s eta 0:00:01
# Collecting ml-dtypes
#   Downloading ml_dtypes-0.5.4-cp39-cp39-macosx_10_9_universal2.whl (676 kB)
#      |████████████████████████████████| 676 kB 795 kB/s eta 0:00:01
# Collecting optree
#   Downloading optree-0.19.0-cp39-cp39-macosx_11_0_arm64.whl (364 kB)
#      |████████████████████████████████| 364 kB 320 kB/s eta 0:00:01
# Collecting lxml
#   Downloading lxml-6.1.0-cp39-cp39-macosx_10_9_universal2.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 911 kB/s eta 0:00:01
# Collecting xmljson
#   Downloading xmljson-0.2.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from scikit-learn->-r requirements.txt (line 29)) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from scikit-learn->-r requirements.txt (line 29)) (1.5.3)
# Requirement already satisfied: filelock in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from chainer->-r requirements.txt (line 30)) (3.19.1)
# Requirement already satisfied: protobuf>=3.0.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from chainer->-r requirements.txt (line 30)) (6.33.6)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from chainer->-r requirements.txt (line 30)) (58.0.4)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting markdown>=2.6.8
#   Using cached markdown-3.9-py3-none-any.whl (107 kB)
# Collecting grpcio>=1.48.2
#   Using cached grpcio-1.80.0-cp39-cp39-macosx_11_0_universal2.whl (12.0 MB)
# Collecting werkzeug>=1.0.1
#   Using cached werkzeug-3.1.8-py3-none-any.whl (226 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 16)) (3.23.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->IPython->-r requirements.txt (line 24)) (0.8.5)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard->-r requirements.txt (line 31)) (8.7.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from pandas>=1.4.0->geopandas->-r requirements.txt (line 25)) (2025.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from pandas>=1.4.0->geopandas->-r requirements.txt (line 25)) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->IPython->-r requirements.txt (line 24)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython->-r requirements.txt (line 24)) (0.5.0)
# Collecting certifi
#   Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Collecting markupsafe>=2.1.1
#   Using cached markupsafe-3.0.3-cp39-cp39-macosx_11_0_arm64.whl (12 kB)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 185 kB/s eta 0:00:01
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from stack-data->IPython->-r requirements.txt (line 24)) (3.0.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from stack-data->IPython->-r requirements.txt (line 24)) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from stack-data->IPython->-r requirements.txt (line 24)) (0.2.3)
# Building wheels for collected packages: libtiff
#   Building wheel for libtiff (setup.py) ... done
#   Created wheel for libtiff: filename=libtiff-0.4.2-cp39-cp39-macosx_26_0_universal2.whl size=208425 sha256=69a58cfa28146e18bc8b396835e7f0ff11b20b7b2ef20cacb74ac5ead6e51884
#   Stored in directory: /Users/paolo/Library/Caches/pip/wheels/31/9e/2b/1e28979ba83201780934daeeb5db3053b505f88b2f69c6c577
# Successfully built libtiff
# Installing collected packages: mdurl, markupsafe, markdown-it-py, certifi, xmljson, werkzeug, tensorboard-data-server, Shapely, rich, pyproj, pyogrio, optree, namex, ml-dtypes, markdown, lxml, h5py, grpcio, absl-py, tensorboard, simplification, libtiff, keras, imgaug, imantics, geopandas
#   Attempting uninstall: Shapely
#     Found existing installation: Shapely 1.8.5.post1
#     Uninstalling Shapely-1.8.5.post1:
#       Successfully uninstalled Shapely-1.8.5.post1
# Successfully installed Shapely-2.0.7 absl-py-2.3.1 certifi-2026.2.25 geopandas-1.0.1 grpcio-1.80.0 h5py-3.14.0 imantics-0.1.12 imgaug-0.4.0 keras-3.10.0 libtiff-0.4.2 lxml-6.1.0 markdown-3.9 markdown-it-py-3.0.0 markupsafe-3.0.3 mdurl-0.1.2 ml-dtypes-0.5.4 namex-0.1.0 optree-0.19.0 pyogrio-0.11.1 pyproj-3.6.1 rich-15.0.0 simplification-0.7.12 tensorboard-2.20.0 tensorboard-data-server-0.7.2 werkzeug-3.1.8 xmljson-0.2.1
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import sys
# !{sys.executable} -m pip install torch torchvision torchaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Downloading torch-2.8.0-cp39-none-macosx_11_0_arm64.whl (73.6 MB)
#      |████████████████████████████████| 73.6 MB 1.2 MB/s eta 0:00:011     |████████████████████████████    | 64.6 MB 15.3 MB/s eta 0:00:01
# Collecting torchvision
#   Downloading torchvision-0.23.0-cp39-cp39-macosx_11_0_arm64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 1.3 MB/s eta 0:00:01
# Collecting torchaudio
#   Downloading torchaudio-2.8.0-cp39-cp39-macosx_11_0_arm64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 12.4 MB/s eta 0:00:01
# Requirement already satisfied: filelock in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from torch) (3.19.1)
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 896 kB/s eta 0:00:011
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 885 kB/s eta 0:00:01
# Requirement already satisfied: networkx in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from torch) (3.2.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from torch) (4.15.0)
# Collecting fsspec
#   Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 1.1 MB/s eta 0:00:01
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: numpy in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from torchvision) (1.26.4)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      |████████████████████████████████| 536 kB 689 kB/s eta 0:00:01
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/paolo/Library/Python/3.9/lib/python/site-packages (from jinja2->torch) (3.0.3)
# Installing collected packages: mpmath, sympy, jinja2, fsspec, torch, torchvision, torchaudio
# Successfully installed fsspec-2025.10.0 jinja2-3.1.6 mpmath-1.3.0 sympy-1.14.0 torch-2.8.0 torchaudio-2.8.0 torchvision-0.23.0
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import torch
import numpy as np
import pandas as pd
import cv2
import shapely

print("All packages loaded successfully")
print("Torch version:", torch.__version__)
# Out:
# All packages loaded successfully
# Torch version: 2.8.0

# %% [markdown]
# # Training, Validation, and Class Weighting Strategy
#
# ## 1. Data Splits: Train, Test, and Hold
#
# The dataset is divided into three distinct subsets, each with a specific role in the machine learning pipeline:
#
# ### Train Split
# The **training set** is used to learn the model parameters. During this phase, the model updates its weights based on the input data and corresponding labels.
#
# ### Test Split
# The **test set** is used during training to evaluate model performance after each epoch. It serves as a **validation set** for:
#
# - monitoring learning progress
# - selecting the best model (e.g., best epoch)
# - comparing configurations or hyperparameters
#
# Importantly, the model does **not learn from the test set**. It is only used for evaluation.
#
# ### Hold Split
# The **holdout set** is used for the **final evaluation** after training is complete. It provides an unbiased estimate of model performance because:
#
# - it is not used during training
# - it is not used for model selection
#
# This separation ensures that reported results reflect true generalization.
#
# ---
#
# ### Summary of Roles
#
# | Split | Purpose |
# |------|--------|
# | Train | Learn model parameters |
# | Test | Model selection and monitoring |
# | Hold | Final unbiased evaluation |
#
# ---
#
# ## 2. Class Imbalance and Class Weights
#
# ### Problem: Imbalanced Data
#
# In the dataset, the distribution of damage classes is highly imbalanced. For example:
#
# - "no-damage" appears far more frequently
# - "minor", "major", and "destroyed" are much less common
#
# Without correction, the model would tend to predict the majority class ("no-damage") to minimize loss, leading to poor performance on rare but important damage categories.
#
# ---
#
# ### Solution: Class-Weighted Loss
#
# To address this, a **class-weighted cross-entropy loss** is used.
#
# Each class is assigned a weight:
#
# ```text
# [0.3402, 2.6667, 2.8210, 3.0202]

# %%
import sys
# !{sys.executable} model/classification_training.py
# Out:
# Loading data...
#
# Split sizes:
# split
# train    159793
# test      53850
# hold      53137
# Name: count, dtype: int64
#
# Train label distribution:
# damage_label
# no-damage       117425
# minor-damage     14980
# major-damage     14161
# destroyed        13227
# Name: count, dtype: int64
#
# Using device: mps
#
# Using class weights: [0.34020224 2.6667724  2.8210049  3.0202048 ]
#
# Starting training...
# Epoch 1/10: 100%|██████████████| 4994/4994 [36:52<00:00,  2.26it/s, loss=1.1275]
# Epoch 01 | Train Loss: 0.8313 | Test Loss: 0.6384 | Test F1: 0.6130 | Time: 39.10 min
# Epoch 2/10: 100%|██████████████| 4994/4994 [24:19<00:00,  3.42it/s, loss=0.5993]
# Epoch 02 | Train Loss: 0.6656 | Test Loss: 0.6451 | Test F1: 0.6329 | Time: 78.95 min
# Epoch 3/10: 100%|██████████████| 4994/4994 [33:42<00:00,  2.47it/s, loss=0.2095]
# Epoch 03 | Train Loss: 0.5724 | Test Loss: 0.5816 | Test F1: 0.6539 | Time: 36.07 min
# Epoch 4/10: 100%|██████████████| 4994/4994 [24:29<00:00,  3.40it/s, loss=0.4315]
# Epoch 04 | Train Loss: 0.4718 | Test Loss: 0.5925 | Test F1: 0.6511 | Time: 26.88 min
# Epoch 5/10: 100%|██████████████| 4994/4994 [24:19<00:00,  3.42it/s, loss=0.3240]
# Epoch 05 | Train Loss: 0.3513 | Test Loss: 0.6624 | Test F1: 0.6536 | Time: 26.73 min
# Epoch 6/10: 100%|██████████████| 4994/4994 [25:51<00:00,  3.22it/s, loss=0.6263]
# Epoch 06 | Train Loss: 0.2572 | Test Loss: 0.7530 | Test F1: 0.6294 | Time: 28.28 min
# Epoch 7/10: 100%|██████████████| 4994/4994 [25:05<00:00,  3.32it/s, loss=0.1074]
# Epoch 07 | Train Loss: 0.2034 | Test Loss: 0.8003 | Test F1: 0.6377 | Time: 27.67 min
# Epoch 8/10: 100%|██████████████| 4994/4994 [25:09<00:00,  3.31it/s, loss=0.1897]
# Epoch 08 | Train Loss: 0.1707 | Test Loss: 0.8260 | Test F1: 0.6470 | Time: 27.55 min
# Epoch 9/10: 100%|██████████████| 4994/4994 [25:19<00:00,  3.29it/s, loss=0.1894]
# Epoch 09 | Train Loss: 0.1496 | Test Loss: 0.8557 | Test F1: 0.6499 | Time: 27.73 min
# Epoch 10/10: 100%|█████████████| 4994/4994 [25:23<00:00,  3.28it/s, loss=0.0860]
# Epoch 10 | Train Loss: 0.1301 | Test Loss: 0.9124 | Test F1: 0.6530 | Time: 27.76 min
#
# Evaluating best model...
#
# Final TEST Macro F1: 0.6539
#               precision    recall  f1-score   support
#
#    no-damage     0.9700    0.8079    0.8816     41427
# minor-damage     0.4436    0.6851    0.5385      4798
# major-damage     0.4093    0.7086    0.5189      3850
#    destroyed     0.5804    0.8106    0.6765      3775
#
#     accuracy                         0.7901     53850
#    macro avg     0.6009    0.7530    0.6539     53850
# weighted avg     0.8557    0.7901    0.8107     53850
#
#
# Final HOLD Macro F1: 0.6669
#               precision    recall  f1-score   support
#
#    no-damage     0.9636    0.7902    0.8683     37971
# minor-damage     0.4797    0.7190    0.5755      6338
# major-damage     0.4402    0.6788    0.5340      4605
#    destroyed     0.6146    0.7855    0.6896      4223
#
#     accuracy                         0.7717     53137
#    macro avg     0.6245    0.7434    0.6669     53137
# weighted avg     0.8328    0.7717    0.7902     53137
#
#
# Saved TEST and HOLD predictions for confusion matrix analysis.
#
# Saved all outputs successfully.

# %% [markdown]
# # Model Performance Analysis and Interpretation
#
# ## 1. Training Dynamics
#
# The training process exhibits a clear pattern of convergence followed by overfitting. Training loss decreases consistently across epochs, while test loss initially decreases and then begins to increase after approximately the third epoch.
#
# The macro F1 score on the test set peaks at **epoch 3 (0.6539)** and does not improve significantly afterward. This indicates that the model achieves its best generalization performance early in training, after which it begins to overfit the training data.
#
# This behavior suggests that:
#
# - the model has sufficient capacity to fit the dataset
# - prolonged training does not improve generalization
# - early stopping would be an effective strategy in this setting
#
# ---
#
# ## 2. Overall Performance
#
# The final performance of the model is summarized below:
#
# | Split | Macro F1 |
# |------|--------|
# | Test | 0.6539 |
# | Hold | 0.6669 |
#
# The slightly higher performance on the holdout set indicates that:
#
# - the model generalizes well beyond the test set
# - there is no evidence of overfitting to the test split
# - the dataset splits are consistent and representative
#
# Overall, a macro F1 score in the range of **0.65–0.67** represents a strong baseline for this task using a standard ResNet50 architecture without extensive hyperparameter tuning.
#
# ---
#
# ## 3. Class-wise Performance
#
# The model exhibits varying performance across damage categories.
#
# ### No-damage
#
# - F1 score: high (≈ 0.87–0.88)
# - strong precision and recall
#
# This is expected due to the high frequency and clear visual characteristics of this class.
#
# ---
#
# ### Minor and Major Damage
#
# - F1 scores: moderate (≈ 0.53–0.58)
# - lower precision compared to recall
#
# These classes are more difficult to distinguish due to:
#
# - subtle visual differences
# - ambiguity between damage levels
# - overlapping feature representations
#
# ---
#
# ### Destroyed
#
# - F1 score: relatively strong (≈ 0.67–0.69)
#
# This class benefits from more distinct visual features, making it easier for the model to identify.
#
# ---
#
# ## 4. Precision–Recall Trade-off
#
# A notable pattern emerges across all damage classes:
#
# - **high recall**
# - **lower precision**
#
# This indicates that the model tends to **over-predict damage**, classifying uncertain cases as damaged rather than undamaged.
#
# This behavior is directly influenced by the use of class-weighted loss.
#
# ---
#
# ## 5. Effect of Class Weights
#
# Class weights were applied to address the strong imbalance in the dataset, where the "no-damage" class dominates.
#
# By assigning higher weights to minority classes, the model is encouraged to prioritize correct classification of damaged buildings.
#
# This leads to:
#
# ### Positive effects
#
# - improved recall for damage classes
# - better detection of rare events
# - more balanced class performance
#
# ### Side effects
#
# - increased false positives for damage
# - confusion between adjacent damage levels
# - reduced precision
#
# This trade-off is expected and reflects a deliberate modeling choice to prioritize detection of damage over conservative classification.
#
# ---
#
# ## 6. Generalization to Holdout Data
#
# The model performs slightly better on the holdout set than on the test set.
#
# This suggests that:
#
# - the model does not overfit the validation process
# - learned features generalize across different disaster scenarios
# - the evaluation protocol is robust
#
# This is an important indicator of model reliability.
#
# ---
#
# ## 7. Limitations
#
# Despite strong baseline performance, several limitations remain:
#
# - difficulty distinguishing between intermediate damage levels
# - sensitivity to class imbalance
# - overfitting after early epochs
# - reliance on bounding box crops without fine-grained localization
#
# These limitations are consistent with known challenges in post-disaster damage classification tasks.
#
# These findings provide a solid foundation for further experimentation and model refinement.

# %% [markdown]
# ## Confusion Matrix

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# =========================
# Load predictions
# =========================
base_path = "/Users/paolo/Desktop/training_outputs/baseline_resnet50"

split = "hold"

y_true = np.load(f"{base_path}/{split}_targets.npy")
y_pred = np.load(f"{base_path}/{split}_preds.npy")

labels = ["no-damage", "minor-damage", "major-damage", "destroyed"]

# =========================
# Raw confusion matrix
# =========================
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(7, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=labels,
    yticklabels=labels,
)

plt.title(f"{split.upper()} Confusion Matrix (Counts)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.show()


# =========================
# Normalized confusion matrix
# =========================
cm_norm = cm.astype("float") / cm.sum(axis=1, keepdims=True)

plt.figure(figsize=(7, 6))
sns.heatmap(
    cm_norm,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    xticklabels=labels,
    yticklabels=labels,
)

plt.title(f"{split.upper()} Confusion Matrix (Normalized)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Confusion Matrix Analysis
#
# The normalized confusion matrix provides insight into the model’s class-wise prediction behavior.
#
# ### Overall Performance
#
# The model shows strong performance along the diagonal, indicating good classification accuracy across all classes. In particular:
#
# - **no-damage** and **destroyed** achieve the highest accuracy (≈ 0.79)
# - **minor-damage** and **major-damage** show slightly lower accuracy (≈ 0.72 and 0.68)
#
# This confirms that the model performs best on visually distinct classes.
#
# ---
#
# ### Error Patterns
#
# The main misclassifications occur between adjacent damage levels:
#
# - **minor-damage → major-damage (0.17)**
# - **major-damage → minor-damage (0.16)**
#
# This indicates difficulty in distinguishing intermediate levels of damage, likely due to subtle visual differences.
#
# Additionally:
#
# - some **no-damage** instances are predicted as **minor-damage (0.10)**
# - some **major-damage** instances are predicted as **destroyed (0.07)**
#
# These errors suggest a tendency to **overestimate damage severity**.
#
# ---
#
# ### Model Bias
#
# The confusion matrix reveals a consistent pattern:
#
# - relatively high recall for damaged classes
# - increased confusion toward more severe categories
#
# This behavior aligns with the use of **class-weighted loss**, which encourages the model to prioritize detecting damage over conservative predictions.
#
# ---
#
# ### Summary
#
# The confusion matrix confirms that:
#
# - the model effectively distinguishes between **no damage** and **severe damage**
# - most errors occur between **adjacent damage categories**
# - the model exhibits a **bias toward predicting higher damage levels**
#
# These findings are consistent with the overall performance metrics and highlight the inherent difficulty of fine-grained damage classification.

# %% [markdown]
# ## Sanity Check: Verification of ResNet50-Based Architecture
#
# Before proceeding with full training and experimentation, a structural sanity check was performed to ensure that the implemented model correctly corresponds to a ResNet50 architecture adapted to the specific task.

# %%
import torch
from torchvision.models import resnet50, ResNet50_Weights
import torch.nn as nn

class ResNet50SixChannel(nn.Module):
    def __init__(self, num_classes=4):
        super().__init__()

        weights = ResNet50_Weights.IMAGENET1K_V2
        self.backbone = resnet50(weights=weights)

        old_conv = self.backbone.conv1
        new_conv = nn.Conv2d(
            in_channels=6,
            out_channels=old_conv.out_channels,
            kernel_size=old_conv.kernel_size,
            stride=old_conv.stride,
            padding=old_conv.padding,
            bias=False,
        )

        with torch.no_grad():
            new_conv.weight[:, :3, :, :] = old_conv.weight
            new_conv.weight[:, 3:, :, :] = old_conv.weight

        self.backbone.conv1 = new_conv
        self.backbone.fc = nn.Linear(self.backbone.fc.in_features, num_classes)

    def forward(self, x):
        return self.backbone(x)

model = ResNet50SixChannel(num_classes=4)

print(model.backbone.conv1)
print(model.backbone.fc)

total_params = sum(p.numel() for p in model.parameters())
print("Total params:", total_params)
# Out:
# Conv2d(6, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# Linear(in_features=2048, out_features=4, bias=True)
# Total params: 23525636

# %% [markdown]
# The structural sanity check confirms that the implemented model correctly corresponds to a ResNet50-based architecture adapted for the task.
#
# ### Key Results
#
# - **Input Layer:**
#   `Conv2d(6, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))`
#   → Confirms successful adaptation from 3 to **6 input channels**, enabling joint processing of pre- and post-disaster imagery.
#
# - **Output Layer:**
#   `Linear(in_features=2048, out_features=4)`
#   → Confirms correct modification of the classifier head for **4 damage classes**, while preserving the standard ResNet50 feature dimension.
#
# - **Parameter Count:**
#   ~23.5 million parameters
#   → Consistent with a **ResNet50-scale model**, accounting for minor changes due to input/output layer modifications.
#
# ### Interpretation
#
# These results verify that:
#
# - The backbone architecture remains **ResNet50**
# - The model is correctly configured for the **6-channel input representation**
# - The classification head matches the **task-specific output space**
#
# ### Conclusion
#
# The sanity check confirms that the model is structurally valid and correctly adapted, ensuring that subsequent training and evaluation are performed on a properly specified ResNet50-based architecture.
# ```
